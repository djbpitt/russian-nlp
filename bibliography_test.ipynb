# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Applications/anaconda3/lib/python3.9/site-packages (3.2.3)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (58.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Peter/.local/lib/python3.9/site-packages (from spacy) (1.22.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (8.0.15)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (0.7.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Applications/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Applications/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Applications/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download ru_core_news_lg
# Out:
# Collecting ru-core-news-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.2.0/ru_core_news_lg-3.2.0-py3-none-any.whl (514.5 MB)
#      |████████████████████████████████| 514.5 MB 33 kB/s  eta 0:00:015     |████████████████████▊           | 333.6 MB 3.7 MB/s eta 0:00:49     |██████████████████████████████▉ | 495.0 MB 3.5 MB/s eta 0:00:06
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Applications/anaconda3/lib/python3.9/site-packages (from ru-core-news-lg==3.2.0) (3.2.3)
# Requirement already satisfied: pymorphy2>=0.9 in /Applications/anaconda3/lib/python3.9/site-packages (from ru-core-news-lg==3.2.0) (0.9.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /Applications/anaconda3/lib/python3.9/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.2.0) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /Applications/anaconda3/lib/python3.9/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.2.0) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /Applications/anaconda3/lib/python3.9/site-packages (from pymorphy2>=0.9->ru-core-news-lg==3.2.0) (0.7.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (4.62.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (8.0.15)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (58.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (21.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (0.9.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Peter/.local/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.22.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (0.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (0.7.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.0.6)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.0.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Applications/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Applications/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Applications/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->ru-core-news-lg==3.2.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')

# %%
pip install spacypdfreader
# Out:
# Collecting spacypdfreader
#   Downloading spacypdfreader-0.2.1-py3-none-any.whl (9.4 kB)
# Collecting pdfminer.six<20211013,>=20211012
#   Downloading pdfminer.six-20211012-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 1.8 MB/s eta 0:00:01
# Collecting rich<11.0.0,>=10.15.2
#   Downloading rich-10.16.2-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 36.4 MB/s eta 0:00:01
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacypdfreader) (3.2.3)
# Requirement already satisfied: cryptography in /Applications/anaconda3/lib/python3.9/site-packages (from pdfminer.six<20211013,>=20211012->spacypdfreader) (3.4.8)
# Requirement already satisfied: chardet in /Applications/anaconda3/lib/python3.9/site-packages (from pdfminer.six<20211013,>=20211012->spacypdfreader) (4.0.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /Applications/anaconda3/lib/python3.9/site-packages (from rich<11.0.0,>=10.15.2->spacypdfreader) (0.4.4)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 37.8 MB/s eta 0:00:01
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Applications/anaconda3/lib/python3.9/site-packages (from rich<11.0.0,>=10.15.2->spacypdfreader) (2.10.0)
# Requirement already satisfied: pathy>=0.3.5 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (0.6.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (8.0.15)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (0.7.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (1.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Peter/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (1.22.3)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (21.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (2.26.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (3.0.6)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (58.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Applications/anaconda3/lib/python3.9/site-packages (from spacy<4.0.0,>=3.0.0->spacypdfreader) (4.62.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /Applications/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.0.0->spacypdfreader) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Applications/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<4.0.0,>=3.0.0->spacypdfreader) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (3.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Applications/anaconda3/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacypdfreader) (8.0.3)
# Requirement already satisfied: cffi>=1.12 in /Applications/anaconda3/lib/python3.9/site-packages (from cryptography->pdfminer.six<20211013,>=20211012->spacypdfreader) (1.14.6)
# Requirement already satisfied: pycparser in /Applications/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography->pdfminer.six<20211013,>=20211012->spacypdfreader) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Applications/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<4.0.0,>=3.0.0->spacypdfreader) (1.1.1)
# Installing collected packages: commonmark, rich, pdfminer.six, spacypdfreader
# Successfully installed commonmark-0.9.1 pdfminer.six-20211012 rich-10.16.2 spacypdfreader-0.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import pickle
import spacy
import srsly
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
from spacy import displacy
from spacy.lang.ru import Russian
from spacy.matcher import Matcher
from collections import Counter
from spacypdfreader import pdf_reader

nlp = spacy.load("ru_core_news_lg")
doc = pdf_reader('/Users/Peter/Desktop/Pipes_Formation/12_Notes_page_329.pdf', nlp)
print(doc.split('^\d+?\.\s\s'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2j/hcx9qgrx2673kjglxzvt92hw0000gn/T/ipykernel_11489/2351916205.py in <module>
#      14 nlp = spacy.load("ru_core_news_lg")
#      15 doc = pdf_reader('/Users/Peter/Desktop/Pipes_Formation/12_Notes_page_329.pdf', nlp)
# ---> 16 print(doc.split('^\d+?\.\s\s'))
#
# AttributeError: 'spacy.tokens.doc.Doc' object has no attribute 'split'

# %%
# Out:
# 'NOTES THE NATIONAL PROBLEM IN RUSSIA 1. N. A. Troinitskii, ed., Pervaia vseobshchaia perepis\' naseleniia Rossiiskoi Imperli, 1.897 g., Obshchii 8VOd, II (St. Petersburg, 1905), 1-19. 2. Slavinskii, in Formy natsional\'nago dvizheniia, 284. 3. Cf. B. E. Nol\'de, "Edinstvo i nerazdel\'nost\' Rossii," Ocherki rosskago gosudarstvennago prava (St. Petersburg, 1911), 1223-554, which contains an excellent historical survey of this problem. 4. Nol\'de, "Edinstvo," 468-554; N. M. Korkunov, Russkoe gosudarstvennoe pravo,I (St. Petersburg, 18g9), 340-50; S. V. Iushkov, Istorlia gosudarstva i pravaSSSR, I (Moscow, 1940), 478-79. 5. V. lvanovskii, "Administrativnoe ustroistvo nashikh okrain," Uchenyia zapiski Imperatorskago Kazanskno Universiteta, LVIII ( 1891), no. 6, 31-37. ag 6. G. B. Sliozberg, Dorevoliutsionnyi stroi Rossii (Paris, 1933), 78-79. 7. Samostiina Ukraina-RUP (Wetzlar, 1917). 8. Protokoly konf erentsii rossiiskikh natsional\' no-sotsialisticheskikh partii ( St. Petersburg, 1908), 94-95. 9. Kastelianslcii, Forrny, 383-95; V. B. Stankevich, Sud\'by narodov Rossii (Berlin,1921), 20-37. 10. L. Rubinshtein, V bor\'be za leninskuiu natsionarnuiu politiku (Kazan, 1930), 30-32. 11. V. Utz, Die Besitzverhaeltnisse der Tatarenbauem im Kreise Simferopol (Tuebingen, 1911 ), 146. 12. S. A. Usov, Istoriko-ekonomicheskie ocherki Kryma (Simferopol, 1925), 53. 13. This and all other population statistics for 1897 are from the official Russian census of that year: Troinitskii, Pervaia vseobshchaia perepis\'. 14. See E. Kirimal, Der nationale Kampf der Krimtuerken, mit besonderer Beruecksichtigung der Jahre 1917-1918 (Emsdetten, 1952), 9-12; D. Validov, Ocherki istorli obrazovannosti i literatury Tatar (do revoliutsii 1.917 g.) { Moscow, 1923). 15. S. Rybakov, "Statistika Musulman v Rossii," Mir Islama, II, no. 11 (1913),762-63; see also Mir Islama, II ( 1913), 193-94. 16, N. Ostrournov, "K istorii musul\'manskogo obrazovatel\'nogo dvizheniia v Rossii v XIX v XX stoletiiakh," Mir Islama, II, no. 5 { 1913), 312. 17. See stenographic reports of the Third Congress, Umum Rusya Miisiilmanlannm 3ncu Resmt Nedvesi (Kazan, 1906; Tarih Kururnu Libra.y, Ankara), Resolution V, Articles 28-30. 18. G. G. lbragimov, Tatary v revoliutsii 1905 goda (Kazan, 1926). 19. M. Z. Mirza-Bala, Milli Azerbaycan Hareketi ( [Berlin], 1938 ), and M.-D. Guseinov, Tiurkskaia demokratlcheskaia partiia federalistoo \'Musaoat\' o proshlom i nastoiashchem, pt. 1 ( [Tillis], 1927 ), 71-78. 20. N. P. Stel\'mashchuk, ed., Kavkazskil Kalendar na 1917 god (Tillis, 1916), 234-37. 21. Z. Avalov, in Kastelianskii, Formy, 482-85. 22. K. Zalevskii, "Natsional\'nyia dvizheniia," Obshchestvennoe doizhenie o Rossll o nachale XX ceka, IV, pt. 2 (St. Petersburg, 1911), 227. 330 NOTES TO CHAPTER I 23. S. F. Tigranian in Kastelianskii, Formy, 505-06. 24. Protokoly konferentsii rossiiskikh natsional\'no-sotsialisticheskikh partii, passim. 25. Programma armianskol revoliutsionnoi i sotsialisticheskol partii Dashnaktsutiun (Geneva, 1908; NNC). 26. Ibid. 27. Cf. I. Borisenlco, Sovetakie respubliki na Sevemom Kavkaze o 1918 godu, II (Rostov on Don, 1930), 23; also V. P. Pozhidaev, Gortsy Sevemogo Kavkaza (Moscow, 1926). 28. F. Engels, Poound Rhein (Stuttgart, 1915), 51. 29. F. Engels, "Gewalt und Oekonomie," NZ, XIV, no. 1 ( 1895-96), 679. 30. F. Engels, in 1852; quoted by H. Cunow, Die Marxsche Geschichts-Gesellschafts-und Staatstheorie, II (Berlin, 1923), 13; see also K. Marx, Revolution and Counter-revolution; or Germany in 1848 (London-New York, 1896),62-64. 31. Articles in Przeglqd Socfaldemokratyczny, partly printed in M. Velikovskii and I. Levin, eds., Natsional\'nyi vopros ( [Moscow], 1931 ). Paul Froelich,Rosa Luxemburg (London, 1940), 45. 32. Verhandlungen des Gesamtparteitages de, Sozialdemokratie in Oesterreich 33. Ibid., 85ff. 34. Ibid., 104. 35. K. Renner, Das Selbstbestimmungsrecht der Natlonen, I (Leipzig-Vienna,1918), 23-24. 36. Bauer, Die Nationalitaetenfrage, 105. 37. Ibid., 3 ...

# %%
# Regex pattern to find citation titles
pattern = r'\n("[^"]*"'
# Try to find matches (returned as an iterator of matches)
results = re.finditer(pattern, text)

# Build a list with the citations found by looping through the matches
# Each match has the first and last indices of the match, relative to the original string
citations = [text[match.start(): match.end()] for match in results]
print("All citations found:", len(citations))
for citation in citations:
    print(citation)
# Two blank lines
print()
print()

# Remove duplicate citations
unique_citations = list(set(citations))
print("Unique citations:", len(unique_citations))
for citation in unique_citations:
    print(citation)
