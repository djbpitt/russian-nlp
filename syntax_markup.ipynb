# %%
from ipymarkup import show_dep_markup as show_markup
from razdel import sentenize, tokenize
from navec import Navec
from slovnet import Syntax

text = "Однажды весной в час небывало жаркого заката в Москве на Патриарших прудах появились два гражданина. Первый из них одетый в летнюю серенькую пару был маленького роста упитан лыс свою приличную шляпу пирожком нес в руке а на хорошо выбритом лице его помещались сверхъестественных размеров очки в черной роговой оправе. Второй – плечистый рыжеватый вихрастый молодой человек в заломленной на затылок клетчатой кепке – был в ковбойке жеваных белых брюках и в черных тапочках."
chunk = []
for sent in sentenize(text):
    tokens = [_.text for _ in tokenize(sent.text)]
    chunk.append(tokens)

navec = Navec.load('navec_news_v1_1B_250K_300d_100q.tar')
syntax = Syntax.load('slovnet_syntax_news_v1.tar')
syntax.navec(navec)

chunk_generator = syntax.map(chunk)
markup = next(chunk_generator)
markup = next(chunk_generator)

# Convert CoNLL-style format to source, target indices
words, deps = [], []
for token in markup.tokens:
    words.append(token.text)
    source = int(token.head_id) - 1
    target = int(token.id) - 1
    if source > 0 and source != target:  # skip root, loops
        deps.append([source, target, token.rel])
show_markup(words, deps)
# Out:
# <div class="tex2jax_ignore"><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; right: 0; border-top-left-radius: 5px; border-left: 1px solid #bdbdbd; transform: skew(-5deg); width: 50%"><span style="display: block; position: absolute; bottom: -1px; width: 0; height: 0; border-left: 3px solid transparent; border-right: 3px solid transparent; border-top: 6px solid #bdbdbd; left: -3px"></span><span style="display: block; position: absolute; top: -10px; line-height: 1; font-size: 9px; color: #9e9e9e; transform: skew(5deg)">nsubj</span></span></span><span style="display: block">Первый</span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span></span><span style="display: block"> </span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 10px; right: 0; border-top-left-radius: 5px; border-left: 1px solid #bdbdbd; transform: skew(-5deg); width: 50%"><span style="display: block; position: absolute; bottom: -1px; width: 0; height: 0; border-left: 3px solid transparent; border-right: 3px solid transparent; border-top: 6px solid #bdbdbd; left: -3px"></span><span style="display: block; position: absolute; top: -10px; line-height: 1; font-size: 9px; color: #9e9e9e; transform: skew(5deg)">case</span></span></span><span style="display: block">из</span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 10px; width: 100%"></span></span><span style="display: block"> </span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 10px; left: 0; border-top-right-radius: 5px; border-right: 1px solid #bdbdbd; transform: skew(5deg); width: 50%"></span></span><span style="display: block">них</span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 100px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span></span><span style="display: block"> </span></span><span style="display: inline-block"><span style="display: block; position: relative; min-width: 5px; height: 130px"><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 120px; right: 0; border-top-left-radius: 5px; border-left: 1px solid #bdbdbd; transform: skew(-5deg); width: 87%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 100px; right: 0; border-top-left-radius: 5px; border-left: 1px solid #bdbdbd; transform: skew(-5deg); width: 75%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 90px; width: 100%"></span><span style="display: block; position: absolute; bottom: 0; border-top: 1px solid #bdbdbd; height: 80px; right: 0; border-top-left-radius: 5px; border-left: 1px solid #bdbdb ...

# %%
type(syntax.map(chunk))
# Out:
# generator

# %%
a = next(syntax.map(chunk))
b = next(syntax.map(chunk))
print(a)
print(b)
# Out:
# SyntaxMarkup(tokens=[SyntaxToken(id='1', text='Однажды', head_id='13', rel='advmod'), SyntaxToken(id='2', text='весной', head_id='13', rel='obl'), SyntaxToken(id='3', text='в', head_id='4', rel='case'), SyntaxToken(id='4', text='час', head_id='2', rel='nmod'), SyntaxToken(id='5', text='небывало', head_id='6', rel='advmod'), SyntaxToken(id='6', text='жаркого', head_id='7', rel='amod'), SyntaxToken(id='7', text='заката', head_id='4', rel='nmod'), SyntaxToken(id='8', text='в', head_id='9', rel='case'), SyntaxToken(id='9', text='Москве', head_id='7', rel='nmod'), SyntaxToken(id='10', text='на', head_id='12', rel='case'), SyntaxToken(id='11', text='Патриарших', head_id='12', rel='amod'), SyntaxToken(id='12', text='прудах', head_id='13', rel='obl'), SyntaxToken(id='13', text='появились', head_id='0', rel='root'), SyntaxToken(id='14', text='два', head_id='15', rel='nummod:gov'), SyntaxToken(id='15', text='гражданина', head_id='13', rel='nsubj'), SyntaxToken(id='16', text='.', head_id='13', rel='punct')])
# SyntaxMarkup(tokens=[SyntaxToken(id='1', text='Однажды', head_id='13', rel='advmod'), SyntaxToken(id='2', text='весной', head_id='13', rel='obl'), SyntaxToken(id='3', text='в', head_id='4', rel='case'), SyntaxToken(id='4', text='час', head_id='2', rel='nmod'), SyntaxToken(id='5', text='небывало', head_id='6', rel='advmod'), SyntaxToken(id='6', text='жаркого', head_id='7', rel='amod'), SyntaxToken(id='7', text='заката', head_id='4', rel='nmod'), SyntaxToken(id='8', text='в', head_id='9', rel='case'), SyntaxToken(id='9', text='Москве', head_id='7', rel='nmod'), SyntaxToken(id='10', text='на', head_id='12', rel='case'), SyntaxToken(id='11', text='Патриарших', head_id='12', rel='amod'), SyntaxToken(id='12', text='прудах', head_id='13', rel='obl'), SyntaxToken(id='13', text='появились', head_id='0', rel='root'), SyntaxToken(id='14', text='два', head_id='15', rel='nummod:gov'), SyntaxToken(id='15', text='гражданина', head_id='13', rel='nsubj'), SyntaxToken(id='16', text='.', head_id='13', rel='punct')])
